# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools
from multiprocessing import Pool
import xlsxwriter
import warnings
warnings.filterwarnings('ignore')

# =============================================================================
# 1. 參數設定與目標
# =============================================================================
DATA_FILE = '資料2.xlsx'
INITIAL_CAPITAL = 10000000
OUTPUT_EXCEL = 'strategy_results.xlsx'
OUTPUT_MD = 'reproduce_report.md'

# %%
# =============================================================================
# 2. 資料讀取與前處理
# =============================================================================
def prepare_data(filepath):
    df = pd.read_excel(filepath)
    df['時間'] = pd.to_datetime(df['時間'])
    df.set_index('時間', inplace=True)
    return df.sort_index()

df_prices = prepare_data(DATA_FILE)

# %%
# =============================================================================
# 3. 雙動能核心引擎
# =============================================================================
def calculate_momentum(prices, periods):
    returns = []
    for p in periods:
        ret = prices.pct_change(p)
        returns.append(ret)
    return pd.concat(returns, axis=1).mean(axis=1)

def run_backtest(price_df, momentum_params, initial_capital=10000000):
    mom_df = pd.DataFrame(index=price_df.index)
    for col in price_df.columns:
        p = momentum_params[col] if isinstance(momentum_params, dict) else momentum_params
        mom_df[col] = calculate_momentum(price_df[col], p)
    
    dates = price_df.index
    holdings = {}
    cash = initial_capital
    equity_curve = []
    detailed_log = []
    
    for i in range(len(dates)):
        date = dates[i]
        curr_prices = price_df.iloc[i]
        curr_mom = mom_df.iloc[i]
        portfolio_value = cash + sum(s * curr_prices[a] for a, s in holdings.items())
        equity_curve.append(portfolio_value)
        valid = curr_mom[curr_mom > 0].sort_values(ascending=False)
        targets = valid.head(2).index.tolist()
        
        # Rebalance
        for a in list(holdings.keys()):
            if a not in targets: cash += holdings.pop(a) * curr_prices[a]
        
        needed = [t for t in targets if t not in holdings]
        if needed:
            for a in needed:
                amount = portfolio_value/2 if len(holdings)==0 and len(targets)==2 else (cash if len(targets)==2 else min(cash, portfolio_value/2))
                if amount > 0 and not np.isnan(curr_prices[a]):
                    holdings[a] = amount / curr_prices[a]; cash -= amount
        
        detailed_log.append({'Date': date, 'Value': portfolio_value, 'Holdings': holdings.copy(), 'Targets': targets})
        
    return pd.Series(equity_curve, index=dates), detailed_log, mom_df

def calculate_metrics(eq):
    cagr = (eq.iloc[-1]/eq.iloc[0])**(52/len(eq)) - 1
    mdd = ((eq - eq.cummax())/eq.cummax()).min()
    return {'CAGR': cagr, 'MaxDD': mdd, 'Calmar': cagr/abs(mdd) if mdd!=0 else 0, 'WinRate': (eq.pct_change() > 0).mean(), 'FinalValue': eq.iloc[-1]}

# %%
# =============================================================================
# 4. 暴力演算參數最佳化 (Global & Per-Asset)
# =============================================================================
def get_candidates():
    c = []
    for p in range(2, 53, 2): c.append([p])
    for p in itertools.combinations(range(2, 53, 4), 2): c.append(list(p))
    return c

candidates = get_candidates()
print(f"測試候選週期組合數: {len(candidates)}")

best_g_calmar = -1; best_g_params = None; plateau = []
for p in candidates:
    eq, _, _ = run_backtest(df_prices, p)
    m = calculate_metrics(eq); m['params'] = str(p); plateau.append(m)
    if m['Calmar'] > best_g_calmar: best_g_calmar = m['Calmar']; best_g_params = p

best_pa_params = {}
for asset in df_prices.columns:
    best_a_calmar = -1; best_a_p = [12]
    # 使用較小集合加速逐標優化
    for p in [c for c in candidates if len(c) <= 2]:
        mom = calculate_momentum(df_prices[asset], p)
        eq_a = [10000000]; s = 0; c = 10000000
        for i in range(len(df_prices)):
            pr = df_prices[asset].iloc[i]; mv = mom.iloc[i]
            if mv > 0 and not np.isnan(pr):
                if s == 0: s = c/pr; c = 0
            else:
                if s > 0: c = s*pr; s = 0
            eq_a.append(c + s*pr if not np.isnan(pr) else (c + s*df_prices[asset].iloc[i-1] if i>0 else c))
        m_a = calculate_metrics(pd.Series(eq_a))
        if m_a['Calmar'] > best_a_calmar: best_a_calmar = m_a['Calmar']; best_a_p = p
    best_pa_params[asset] = best_a_p

eq_pa, _, _ = run_backtest(df_prices, best_pa_params); m_pa = calculate_metrics(eq_pa)
if best_g_calmar >= m_pa['Calmar']: best_params, winner_type = best_g_params, 'Global'
else: best_params, winner_type = best_pa_params, 'Per-Asset'
print(f"最佳化方式: {winner_type}, 參數: {best_params}")
# Out:
# 測試候選週期組合數: 104
# 最佳化方式: Global, 參數: [6, 18]

# %%
# =============================================================================
# 5. 生成成果檔案
# =============================================================================
final_eq, final_log, final_mom = run_backtest(df_prices, best_params)
metrics = calculate_metrics(final_eq)

writer = pd.ExcelWriter(OUTPUT_EXCEL, engine='xlsxwriter')
# Trades sheet
trades = []
for i, e in enumerate(final_log):
    d = e['Date']; h = e['Holdings']
    all_a = set(list(h.keys()) + [s['Asset'] for s in e.get('Sold', [])]) # Handle missing Sold
    # Re-derive sold/kept/bought for trades sheet
    for a in all_a:
        # Simplification for sheet generation
        p_cur = df_prices.loc[d, a]
        m_v = final_mom.loc[d, a]
        trades.append({'日期': d, '標的': a, '價格': p_cur, '動能': m_v})
pd.DataFrame(trades).to_excel(writer, sheet_name='Trades', index=False)
# Summary
pd.DataFrame({'指標': metrics.keys(), '數值': metrics.values()}).to_excel(writer, sheet_name='Summary', index=False)
writer.close()

with open(OUTPUT_MD, 'w') as f:
    f.write(f"# 報告\nCalmar: {metrics['Calmar']:.2f}\n")
    f.write(pd.DataFrame(plateau).sort_values('Calmar', ascending=False).head(10).to_markdown(index=False))

final_eq.plot(title='Final Equity')
plt.show()
